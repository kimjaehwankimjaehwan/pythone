# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/data/202104.csv', low_memory=False)
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
new_df = df.drop(columns=['Unnamed: 13'])
new_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
new_df.columns
# Out:
# Index(['번호', '도서명', '저자', '출판사', '발행년도', 'ISBN', '세트 ISBN', '부가기호', '권',
#        '주제분류번호', '도서권수', '대출건수', '등록일자'],
#       dtype='object')

# %%
new_df.isna().mean()
# 결측치가 없는 데이터만 추출
new_df.isna().mean() == 0
temp = new_df.isna().mean()
temp[temp == 0].index
# Out:
# Index(['번호', 'ISBN', '도서권수', '대출건수', '등록일자'], dtype='object')

# %%
# 결측치가 없는 컬럼만 추출
df.loc[:,temp[temp == 0].index]
# Out:
#             번호           ISBN  도서권수  대출건수        등록일자
# 0            1  9788937444319     1     0  2021-03-19
# 1            2  9791190123969     1     0  2021-03-19
# 2            3  9788968332982     1     0  2021-03-19
# 3            4  9788970759906     1     0  2021-03-19
# 4            5  9788934990833     1     0  2021-03-19
# ...        ...            ...   ...   ...         ...
# 401677  401678  9788977352971     1     0  1970-01-01
# 401678  401679  9788985367448     1     0  1970-01-01
# 401679  401680  9788937401596     1     0  1970-01-01
# 401680  401681  9788947700368     2     0  1970-01-01
# 401681  401682  9788970610092     0     0  1970-01-01
#
# [401682 rows x 5 columns]

# %%
# 모든 row가 na인 row만 삭제
na_book = df.dropna(axis=1, how = 'all')
na_book
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# ...

# %%
# 행을 삭제
na_book.drop([0,1])
# Out:
#             번호                                  도서명                    저자  \
# 2            3                나도 한 문장 잘 쓰면 바랄 게 없겠네                김선영 지음
# 3            4                              예루살렘 해변      이도 게펜 지음, 임재희 옮김
# 4            5                김성곤의 중국한시기행 : 장강·황하 편                김성곤 지음
# 5            6                        처음 읽는 음식의 세계사  미야자키 마사카츠 지음, 한세희 옮김
# 6            7  아르센 벵거 자서전 My Life in Red and White     아르센 벵거 지음, 이성모 옮김
# ...        ...                                  ...                   ...
# 401677  401678                              韓國現代詩大系                채만묵 編著
# 401678  401679                                뉴 웨이브            제임스 모나코 지음
# 401679  401680                         (최인훈 장편소설)화두                최인훈 지음
# 401680  401681                         독일 문학과 세계 문학                吳漢鎭 編著
# 401681  401682                           참으로 소중한 생각                김일상 지음
#
#                  출판사  발행년도           ISBN        세트 ISBN 부가기호    권   주제분류번호  \
# ...

# %%
# 출판사 김영사인 데이터만 추출
na_book[na_book['출판사'] == '김영사']
# Out:
#             번호                                          도서명  \
# 4            5                        김성곤의 중국한시기행 : 장강·황하 편
# 132        133  (빌 게이츠)기후재앙을 피하는 법:우리가 가진 솔루션과 우리에게 필요한 돌파구
# 217        218                  마음의 짐을 안고 있는 당신에게(인문1, 독치1)
# 710        711                         뻔하지 않고 실용적인 원격근무 안내서
# 715        716                     빌 게이츠, 기후재앙을 피하는 법(스마트2)
# ...        ...                                          ...
# 401374  401375                                   더불어 사는 사람들
# 401380  401381                                         제주기행
# 401388  401389                                        住宅政策論
# 401396  401397                                    노턴 안티바이러스
# 401452  401453                                   이런 사원을 뽑아라
#
#                          저자  출판사   발행년도           ISBN 세트 ISBN 부가기호    권  \
# 4                    김성곤 지음  김영사   2021  9788934990833     NaN  NaN  NaN
# 132      빌 게이츠 지음;김민주;이엽 옮김  김영사   2021  9788934991366     NaN    0  NaN
# ...

# %%
# 대출건수가 1000건 이상인 항목만 추출
na_book[na_book['대출건수'] >= 1000]
# Out:
#             번호                                      도서명                 저자  \
# 94781    94782  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문   유발 하라리 지음 ;조현욱 옮김
# 346944  346945                         해커스 토익:Listening       David Cho 지음
#
#              출판사  발행년도           ISBN 세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 94781        김영사  2016  9788934972464     NaN  NaN  NaN     909    30  1468
# 346944  해커스어학연구소  2005  9788990700148     NaN    1  NaN  740.77    29  1065
#
#               등록일자
# 94781   2016-04-22
# 346944  2005-02-01

# %%
# 중복된 행을 찾기 - 전체
sum(na_book.duplicated())
# Out:
# 0

# %%
sum(na_book.duplicated(subset = ['도서명','저자','ISBN']))
# Out:
# 22096

# %% [markdown]
# # 클리닝 함수 - 데이터전처리

# %%
filename = '/content/drive/MyDrive/data/202104.csv'
def data_cleaning(filename):
  # 파일을 데이터 프레임으로 읽기
  ns_df = pd.read_csv(filename, low_memory=False)
  # NaN인 열을 삭제
  ns_book = ns_df.dropna(axis=1, how = 'all')

  # 대출건수를 합치기 위해서 필요한 행만 추출해서 count_df 프레임을 만든다
  count_df =  ns_book[['도서명','저자','ISBN','권','대출건수']]
  # 도서명 저자 isgn 권을 기준으로 대출건수를 goupby
  loan_df = count_df.groupby(['도서명','저자','ISBN','권'],dropna=False).sum()
  # 원본데이터에서 중복된 행을 제외하고 고유한 행만 추출해서복사
  dup_rows = ns_book.duplicated(subset = ['도서명','저자','ISBN'])
  unique_rows = ~dup_rows
  ns_book3 = ns_book[unique_rows].copy()
  # 도서명, 저자, ISBN, 권을 인덱스로 설정
  ns_book3.set_index(['도서명','저자','ISBN','권'],inplace=True)
  # load_count에 저장된 누적 대출건수를 업데이트
  ns_book3.update(loan_df)

  # 인덱스를 재 설정
  ns_book4 = ns_book3.reset_index()
  # 원본 데이터프레임의 열 순서를 변경
  ns_book4 = ns_book4[ns_book.columns]
  return ns_book

# %%
data_cleaning('/content/drive/MyDrive/data/202104.csv')
# Out:
#             번호                    도서명                저자    출판사  발행년도  \
# 0            1                인공지능과 흙            김동훈 지음    민음사  2021
# 1            2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2            3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3            4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4            5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
# ...        ...                    ...               ...    ...   ...
# 401677  401678                韓國現代詩大系            채만묵 編著  한국문화사  1996
# 401678  401679                  뉴 웨이브        제임스 모나코 지음    한나래  1996
# 401679  401680           (최인훈 장편소설)화두            최인훈 지음    민음사  1994
# 401680  401681           독일 문학과 세계 문학            吳漢鎭 編著     벽호  1995
# 401681  401682             참으로 소중한 생각            김일상 지음    동문사  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 0       9788937444319            NaN  NaN  NaN      NaN     1     0
# ...
