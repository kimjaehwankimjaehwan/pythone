# %% [markdown]
# # 자료구조

# %% [markdown]
# ## 스텍
#   - 컵쌓기, 프링글스, 식판
#   - 함수 호출

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 리스트를 이용한 스텍 구현하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 스텍에 데이터 삽입하기

# %%
stack = []   # 비어있는 리스트를 만든다
# stack.append(10)
# stack.append(20)
# push함수 작성
def push(data):
  stack.append(data)
def pop():
  return stack.pop(-1)   if len(stack) > 0 else None

def top():
  return stack[-1]  if len(stack) > 0 else None

def isEmpty():
  return False if len(stack) > 0 else True

def popAll():
  stack.clear()
def print_stack_all():
  for i in range(-1,-len(stack)-1,-1):  # -1 -2 -3
    print(stack[i])
  # for i in range(len(stack)-1,-1,-1):  # 5 4 3 2
  #   print(stack[i])

# %%
# 스텍을 구성하는 기능들을 한번씩 사용해 보기
# 스텍의 데이터를 전부 출력하는 함수를 작성( 리스트를 거꾸로 출력)

# %%
import random
for i in range(5):
  push(random.randint(1,100) )
stack
# Out:
# [98, 41, 27, 61, 50]

# %%
for i in range(-1,-len(stack)-1,-1):
  print(stack[i])
for i in range(len(stack)-1,-1,-1):
  print(stack[i])
# Out:
# 50
# 61
# 27
# 41
# 98
# 50
# 61
# 27
# 41
# 98

# %% [markdown]
# ## stack의 적용분야(예제)

# %%
# {([({})])}
# 괄호가 짝이 맞는지 조사
stack = []
express = '((())})'
def is_balance(express):
  for i in express:
    if i in '[{(':  # 여는 괄호면 스텍에 쌓는다
      push(i)
    elif i in ')}]':
      p = pop()
      if ( i == ')' and p != '(' ) or ( i=='}' and p != '{' ):
        return False
  return isEmpty()

is_balance(express)
# Out:
# False

# %%
# 문자열 뒤집기 - stack
test = 'hello'
# olleh
stack = []  # 스텍 초기화
for i in test:
  push(i)

result = ''
for i in range(len(test)):
  result += pop()
result
# Out:
# 'olleh'

# %% [markdown]
# # 큐(Queue)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
queue = []
def enqueue(data):  # 리스트(큐)의 맨 마지막에 데이터를 추가한다
  queue.append(data)
def dequeue():  # 리스트(규)의 맨 앞에 있는 원소를 가져오고 삭제한다
  return queue.pop(0) if not isEmpty() else None   # 비어있지 않으면 pop(0)를 실행하고 그렇지 않으면 None을 출력
def front():   # 리스트(규)의 맨 앞에 있는 원소를 알려준다
  return queue[0] if not isEmpty() else None
def isEmpty(): # 리스트(규)가 비어있는지 알려준다
  return False if len(queue) > 0 else True
def dequeueAll(): # 리스트(규)를 전부 삭제한다
  queue.clear()
def printQueue():
  for i in queue:
    print(i,end=' ')
  print()

# %%
# 임의의 숫자를 10번 큐에 넣기
queue = []
import random
[ enqueue(random.randint(1,100))  for i in range(10) ]
print(queue)
# 큐에 데이터를 전부 삭제하기
dequeueAll()
print(queue)
# dequeue()  실행하기  -- error
print( dequeue() )
# front() 실행하기 -- error
print(front())
# 만약에 에러가발생하면 에러가 안나도록 예외처리 하기
# Out:
# [99, 49, 96, 8, 63, 78, 62, 21, 76, 59]
# []
# None
# None

# %%
# 정상적으로 읽거나 꺼꾸로 읽어도 같은 단어이면 True 그렇지 않으면 False를 리턴하는 기능을 Stack 또는 Queue를 이용해서 구현
# abbbba

stack = []
queue = []

target = input("문자열을 입력하세요")
def checkSame(target):
  for i in target:  # stack에 쌓기
    push(i)

  # stack에 데이터를 꺼내서 queue에  쌓기
  for i in range(len(stack)):
    enqueue(pop())

  return target == ''.join(queue)

checkSame(target)
# Out:
# 문자열을 입력하세요abbbba
# True
