# %% [markdown]
# 판다스를 이용한 전처리

# %%
# 파일 열기
f = open('data.txt', 'r')  # r은 읽기 모드.. 파일이 없으면 오류
f = open('data.txt', 'w')  # w은 쓰기 모드.. 파일이 없으면 새로 생성, 있으면 기존내용을 덮어쓴다
f = open('data.txt', 'rt+')  # 읽기 쓰기모드로 기존파일의 맨 뒤에서부터 내용을 추가
f = open('data.txt', 'wt+')  # 읽기 쓰기모드로 기존파일의 내용을 지우고 처음부터 쓴다
f.write('hello')  # 파일에 기록
f.close()  # 파일을 닫는다

# %%
with open('data.txt', 'w') as f:
    f.write('hello')

# %%
# !unzip 'data.zip' -d data
# Out:
# Archive:  data.zip
# replace data/file.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/file.txt
#   inflating: data/hello.txt
#   inflating: data/proverb.txt

# %%
import glob
import os

# %%
#glob.glob('data/*',recursive=True)  # recursive=True 하위경로에 있는 모든 파일을 가져온다

# %%
os.path.join('abc','efg',"*.txt")
# Out:
# 'abc/efg/*.txt'

# %%
for filename in glob.glob('data/*'):
  with open(filename,'r',encoding='utf-8') as f:
      print(f.read())
# Out:
# 안녕하세요
# hello
# 내용을 추가합니다.
# 저장하는 문서 이름,  'w' 대신 'a'를 사용합니다.
#
# 작은 일에 성실한 사람은 큰 일에도 성실하고,
# 작은 일에 정직하지 못한 사람은 큰 일에도 정직하지 못하다.
# 누가복음 16:10
#
# 변함없이 서로 사랑하는 이가 친구이며
# 위급할 때 서로 돕는 이가 형제이다.
# 잠언 17:17
# 작은 일에 성실한 사람은 큰 일에도 성실하고,
# 작은 일에 정직하지 못한 사람은 큰 일에도 정직하지 못하다.
# 누가복음 16:10
#
# 변함없이 서로 사랑하는 이가 친구이며
# 위급할 때 서로 돕는 이가 형제이다.
# 잠언 17:17

# %%
# 문자열 분리  split
txt = '변함없이, 서로, 사랑하는, 이가, 친구이며'
print( txt.split(",") )

print( [word.strip()  for word in txt.split(',') ] )
list(map(lambda w:w.strip(), txt.split(',')))
# Out:
# ['변함없이', ' 서로', ' 사랑하는', ' 이가', ' 친구이며']
# ['변함없이', '서로', '사랑하는', '이가', '친구이며']
# ['변함없이', '서로', '사랑하는', '이가', '친구이며']

# %% [markdown]
# 웹페이지에서 CSV 가져오기

# %%
import pandas as pd
titanic_df = pd.read_csv('https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv',delimiter='\t')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df = pd.read_csv('https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv',sep='\t')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 엑셀파일 가져오기

# %%
titanic = 'https://github.com/sehakflower/data/blob/main/titanic.xlsx?raw=true'
titanic = pd.read_excel(titanic,sheet_name='titanic3')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# # 데이터 처리

# %% [markdown]
# ### 데이터 살펴보기 앞, 뒤  head() tail()

# %%
titanic_df.head(3)  # 기본이 5개... 매개변수 값을 주면 해당 값만큼
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ### 데이터개수 확인 및 형태확인  len / shape 함수

# %%
len(titanic_df),  titanic_df.shape
# Out:
# (156, (156, 12))

# %% [markdown]
# ### 기본 통계치 보기

# %%
titanic_df.describe() # 컬럼이 총 12개인데.. why 7개만 나왔을까?  수치형 데이터에 대한 통계
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_df.describe(include='object') # 범주형 데이터에 대한 통계
# Out:
#                            Name   Sex Ticket        Cabin Embarked
# count                       156   156    156           31      155
# unique                      156     2    145           28        3
# top     Braund, Mr. Owen Harris  male   2651  C23 C25 C27        S
# freq                          1   100      2            2      110

# %%
titanic_df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    156.000000  156.000000  156.000000                      156   156
# unique          NaN         NaN         NaN                      156     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   100
# mean      78.500000    0.346154    2.423077                      NaN   NaN
# std       45.177428    0.477275    0.795459                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%       39.750000    0.000000    2.000000                      NaN   NaN
# 50%       78.500000    0.000000    3.000000                      NaN   NaN
# 75%      117.250000    1.000000    3.000000                      NaN   NaN
# max      156.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ### 결측치와 데이터형 확인하기 info()

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %% [markdown]
# ## 열/행 정리
# ### 열 이름 변경

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 컬럼명을 전부 소문자로 변경해서 데이터프레임에 반영해 주세요
titanic_df.columns =  titanic_df.columns.str.lower()

# %%
titanic_df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 데이터 프레임 복사

# %%
copy_titanic = titanic_df.copy()
copy_titanic['passengerid'][0] = 100
copy_titanic.head()
# Out:
# <ipython-input-22-fdb9ecb7311e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   copy_titanic['passengerid'][0] = 100
#    passengerid  survived  pclass  \
# 0          100         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
# ...

# %%
titanic_df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 람다 함수
#   - 익명의 함수
#   - 함수이름은 없고 함수의 동작만 정의
#   - 함수 자체를 매개변수로 하는 또 다른 함수에서 사용
#   - 불필요한 함수를 미리 만들지 않아도.. 사용하고 없어진다.

# %%
def myfunc(x):
  return x+1

# %%
list_1 = [1,3,5,7,9]
list( map(myfunc,list_1) )
# Out:
# [2, 4, 6, 8, 10]

# %%
list( map( lambda x: x+1 ,list_1) )
# Out:
# [2, 4, 6, 8, 10]

# %%
def filter_5_over(x):
  return x > 5

list( filter(filter_5_over, list_1) )
# Out:
# [7, 9]

# %%
list( filter(lambda x: x>5, list_1) )
# Out:
# [7, 9]

# %% [markdown]
# ### 행 추가

# %%
temp = pd.DataFrame( [[1,1,1,'name','male',1,1,1,'ticket',1,'cabin','embarked']], columns=titanic_df.columns)
copy_titanic = pd.concat([copy_titanic,temp]).reset_index(drop=True)
copy_titanic
# Out:
#      passengerid  survived  pclass  \
# 0            100         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
# 156            1         1       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 열 추가

# %%
# gnder 컬럼을 추가하고 값은 1로 채워 넣습니다.
copy_titanic['gender'] = 1
copy_titanic
# Out:
#      passengerid  survived  pclass  \
# 0            100         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
# 156            1         1       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### values 속성

# %%
copy_titanic.values
# Out:
# array([[100, 0, 3, ..., nan, 'S', 1],
#        [2, 1, 1, ..., 'C85', 'C', 1],
#        [3, 1, 3, ..., nan, 'S', 1],
#        ...,
#        [155, 0, 3, ..., nan, 'S', 1],
#        [156, 0, 1, ..., nan, 'C', 1],
#        [1, 1, 1, ..., 'cabin', 'embarked', 1]], dtype=object)

# %% [markdown]
# ### 열 추출 : age

# %%
copy_titanic['age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %% [markdown]
# ### 정렬 하기
#   - index기준
#   - 컬럼명 기준으로

# %%
copy_titanic.sort_index()
# Out:
#      passengerid  survived  pclass  \
# 0            100         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
# 156            1         1       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
copy_titanic.sort_index(ascending=False)
# Out:
#      passengerid  survived  pclass  \
# 156            1         1       1
# 155          156         0       1
# 154          155         0       3
# 153          154         0       3
# 152          153         0       3
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0            100         0       3
#
#                                                   name     sex   age  sibsp  \
# 156                                               name    male   1.0      1
# 155                        Williams, Mr. Charles Duane    male  51.0      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 열기준으로 정렬

# %%
copy_titanic.sort_values(by='age')  # 오름차순
copy_titanic.sort_values(by='age',ascending=False)  # 내림차순
# Out:
#      passengerid  survived  pclass                            name     sex  \
# 96            97         0       1       Goldschmidt, Mr. George B    male
# 116          117         0       3            Connors, Mr. Patrick    male
# 33            34         0       2           Wheadon, Mr. Edward H    male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius    male
# 94            95         0       3               Coxon, Mr. Daniel    male
# ..           ...       ...     ...                             ...     ...
# 121          122         0       3      Moore, Mr. Leonard Charles    male
# 126          127         0       3             McMahon, Mr. Martin    male
# 128          129         1       3               Peter, Miss. Anna  female
# 140          141         0       3   Boulos, Mrs. Joseph (Sultana)  female
# 154          155         0       3           Olsen, Mr. Ole Martin    male
#
#       age  sibsp  parch      ticket     fare  cabin embarked  gender
# ...

# %%
# 나이별 선실등급
copy_titanic.sort_values(by=['age','pclass'])
# Out:
#      passengerid  survived  pclass                               name     sex  \
# 78            79         1       2      Caldwell, Master. Alden Gates    male
# 156            1         1       1                               name    male
# 7              8         0       3     Palsson, Master. Gosta Leonard    male
# 16            17         0       3               Rice, Master. Eugene    male
# 119          120         0       3  Andersson, Miss. Ellis Anna Maria  female
# ..           ...       ...     ...                                ...     ...
# 121          122         0       3         Moore, Mr. Leonard Charles    male
# 126          127         0       3                McMahon, Mr. Martin    male
# 128          129         1       3                  Peter, Miss. Anna  female
# 140          141         0       3      Boulos, Mrs. Joseph (Sultana)  female
# 154          155         0       3              Olsen, Mr. Ole Martin    male
#
# ...

# %%
# copy_titanic[0]  # keyError  key == column name

# %% [markdown]
# ### 지정한 범위의 행에서 데이터가져오기

# %%
# copy_titanic.head()
copy_titanic[0:5]  # 처음부터 5개의 row
copy_titanic[0:1]  # 한개
copy_titanic[::3]  #  3개씩 건너서 출력
copy_titanic[::-1] # 역순으로 출력
# Out:
#      passengerid  survived  pclass  \
# 156            1         1       1
# 155          156         0       1
# 154          155         0       3
# 153          154         0       3
# 152          153         0       3
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0            100         0       3
#
#                                                   name     sex   age  sibsp  \
# 156                                               name    male   1.0      1
# 155                        Williams, Mr. Charles Duane    male  51.0      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### loc 함수 iloc 함수 알아보기
#    - 데이터 프레임의 행 렬을 가져온다

# %%
copy_titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0          100         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked  gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       1
# 3      0            113803  53.1000  C123        S       1
# ...

# %%
copy_titanic.loc[0:4, 'passengerid':'pclass']
# Out:
#    passengerid  survived  pclass
# 0          100         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
copy_titanic.iloc[0:4, 0:3]
# Out:
#    passengerid  survived  pclass
# 0          100         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1

# %% [markdown]
# ### 피벗테이블

# %%
copy_titanic.pivot_table(index='pclass',columns='sex',values='age',aggfunc='mean')
# Out:
# sex        female       male
# pclass
# 1       35.250000  37.400000
# 2       24.625000  30.578235
# 3       21.203704  26.255814

# %%
# 선실등급별 성별에따른 생존유무를 피벗테이블로 구현
copy_titanic.pivot_table(index='pclass',columns='sex',values='survived',aggfunc='mean')
# Out:
# sex       female      male
# pclass
# 1       1.000000  0.181818
# 2       0.916667  0.166667
# 3       0.571429  0.131148

# %%
import numpy as np
copy_titanic.pivot_table(index='pclass',columns='sex',values='survived',aggfunc=np.mean)
# Out:
# <ipython-input-44-88b9605ecb37>:2: FutureWarning: The provided callable <function mean at 0x7b422c50fd00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   copy_titanic.pivot_table(index='pclass',columns='sex',values='survived',aggfunc=np.mean)
# sex       female      male
# pclass
# 1       1.000000  0.181818
# 2       0.916667  0.166667
# 3       0.571429  0.131148

# %% [markdown]
# ### 그룹으로 묶기

# %%
copy_titanic.groupby('pclass').count()
# Out:
#         passengerid  survived  name  sex  age  sibsp  parch  ticket  fare  \
# pclass
# 1                31        31    31   31   28     31     31      31    31
# 2                30        30    30   30   29     30     30      30    30
# 3                96        96    96   96   70     96     96      96    96
#
#         cabin  embarked  gender
# pclass
# 1          25        30      31
# 2           4        30      30
# 3           3        96      96

# %%
copy_titanic.select_dtypes(include='number').groupby('survived').mean()
# Out:
#           passengerid    pclass        age     sibsp     parch       fare  \
# survived
# 0           85.794118  2.490196  29.358824  0.666667  0.372549  27.271076
# 1           65.363636  2.272727  25.031667  0.527273  0.454545  29.171742
#
#           gender
# survived
# 0            1.0
# 1            1.0

# %%
copy_titanic.select_dtypes(include='object').groupby('embarked').count()
# Out:
#           name  sex  ticket  cabin
# embarked
# C           32   32      32      9
# Q           13   13      13      0
# S          110  110     110     21
# embarked     1    1       1      1

# %% [markdown]
# ### 데이터 정제하기

# %%
import gdown
gdown.download('https://bit.ly/3RhoNho', 'ns_202104.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3RhoNho
# To: /content/ns_202104.csv
# 100%|██████████| 57.6M/57.6M [00:00<00:00, 66.1MB/s]
# 'ns_202104.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/ns_202104.csv',low_memory=False)
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401682 entries, 0 to 401681
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   번호           401682 non-null  int64
#  1   도서명          401279 non-null  object
#  2   저자           401481 non-null  object
#  3   출판사          396887 non-null  object
#  4   발행년도         401665 non-null  object
#  5   ISBN         401682 non-null  object
#  6   세트 ISBN      61871 non-null   object
#  7   부가기호         325034 non-null  object
#  8   권            68267 non-null   object
#  9   주제분류번호       381360 non-null  object
#  10  도서권수         401682 non-null  int64
#  11  대출건수         401682 non-null  int64
#  12  등록일자         401682 non-null  object
#  13  Unnamed: 13  0 non-null       float64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 42.9+ MB

# %%
# 결측치 확인하기
df.isna().mean()
# Out:
# 번호             0.000000
# 도서명            0.001003
# 저자             0.000500
# 출판사            0.011937
# 발행년도           0.000042
# ISBN           0.000000
# 세트 ISBN        0.845970
# 부가기호           0.190818
# 권              0.830047
# 주제분류번호         0.050592
# 도서권수           0.000000
# 대출건수           0.000000
# 등록일자           0.000000
# Unnamed: 13    1.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.barplot(df.isna().mean())
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# !apt-get install -y fonts-nanum*
# !rm -rf /root/.cache/matplotlib/* # 폰트 캐시 재설정
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# fonts-nanum is already the newest version (20200506-1).
# fonts-nanum-coding is already the newest version (2.5-3).
# fonts-nanum-eco is already the newest version (1.000-7).
# fonts-nanum-extra is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import matplotlib as mpl

path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

font_name = mpl.font_manager.FontProperties(fname=path).get_name()

plt.rcParams['font.family'] = font_name

# %%
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df = df.iloc[:,:-1]
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
# 결측치가 있는 컬럼은 데이터 프레임에서 제외한다.
df_na_column = df.dropna(axis=1)  # 컬럼기준으로   axis = 0 row중에서 결측치가 있는 row는 제외
df_na_column.head()
# Out:
#    번호           ISBN  도서권수  대출건수        등록일자
# 0   1  9788937444319     1     0  2021-03-19
# 1   2  9791190123969     1     0  2021-03-19
# 2   3  9788968332982     1     0  2021-03-19
# 3   4  9788970759906     1     0  2021-03-19
# 4   5  9788934990833     1     0  2021-03-19

# %%
df_na_row = df.dropna(axis=0)  # 컬럼기준으로   axis = 0 row중에서 결측치가 있는 row는 제외
df_na_row.head()
# Out:
#       번호  도서명              저자   출판사  발행년도           ISBN        세트 ISBN 부가기호  \
# 109  110  파친코  이민진 지음 ;이미정 옮김  문학사상  2018  9788970129815  9788970129808    0
# 110  111  파친코  이민진 지음 ;이미정 옮김  문학사상  2018  9788970129822  9788970129808    0
# 126  127  파친코  이민진 지음 ;이미정 옮김  문학사상  2018  9788970129815  9788970129808    0
# 127  128  파친코  이민진 지음 ;이미정 옮김  문학사상  2018  9788970129815  9788970129808    0
# 128  129  파친코  이민진 지음 ;이미정 옮김  문학사상  2018  9788970129822  9788970129808    0
#
#      권 주제분류번호  도서권수  대출건수        등록일자
# 109  1  843.6     1     0  2021-03-12
# 110  2  843.6     1     0  2021-03-12
# 126  1  843.6     1     0  2021-03-12
# 127  1  843.6     1     0  2021-03-12
# 128  2  843.6     1     0  2021-03-12

# %%
# 출판사가 '김영사'인 데이터만 추출
df[df['출판사'] == '김영사']
# Out:
#             번호                                          도서명  \
# 4            5                        김성곤의 중국한시기행 : 장강·황하 편
# 132        133  (빌 게이츠)기후재앙을 피하는 법:우리가 가진 솔루션과 우리에게 필요한 돌파구
# 217        218                  마음의 짐을 안고 있는 당신에게(인문1, 독치1)
# 710        711                         뻔하지 않고 실용적인 원격근무 안내서
# 715        716                     빌 게이츠, 기후재앙을 피하는 법(스마트2)
# ...        ...                                          ...
# 401374  401375                                   더불어 사는 사람들
# 401380  401381                                         제주기행
# 401388  401389                                        住宅政策論
# 401396  401397                                    노턴 안티바이러스
# 401452  401453                                   이런 사원을 뽑아라
#
#                          저자  출판사   발행년도           ISBN 세트 ISBN 부가기호    권  \
# 4                    김성곤 지음  김영사   2021  9788934990833     NaN  NaN  NaN
# 132      빌 게이츠 지음;김민주;이엽 옮김  김영사   2021  9788934991366     NaN    0  NaN
# ...
