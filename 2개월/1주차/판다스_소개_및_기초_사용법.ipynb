# %% [markdown]
# 주피터 노트북 사용자의 경우
# 판다스 라이브러리가 설치되어 있지 안다면 아래의 코드를 실행후 사용

# %%
# !pip install pandas

# %% [markdown]
# #Section 02. 시리즈
# ### 리스트 데이터를 판다스 시리즈로 직접 변환하기

# %%
import pandas as pd
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd_s=pd.Series([1, 2, 3, 4, 5])
type(pd_s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 리스트 변수를 판다스 시리즈로 변환하기

# %%
pd_l=[1, 2, 3, 4, 5]
pd_s1=pd.Series(pd_l)
print(pd_s1)
type(pd_s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# pandas.core.series.Series

# %%
# 따라해 보기
# 자유롭게 시리즈데이터를 만들어 보세요

# %% [markdown]
# #Section 03. 데이터 프레임
# ##1. 데이터프레임 생성
# ### 1차원 리스트를 데이터프레임으로 변환하기
#
#
# ![image.png](data:image/png;base64,...)

# %%
pd_l=[1, 2, 3, 4, 5]
pd.Series(pd_l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd_s2=pd.DataFrame(pd_l)
pd_s2
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
type(pd_s2)
# Out:
# pandas.core.frame.DataFrame

# %%
pd_l=[1, 2, 3, 4, 5]
pd_s2=pd.DataFrame(pd_l)
pd_s2['1열']=pd_l
pd_s2
# Out:
#    0  1열
# 0  1   1
# 1  2   2
# 2  3   3
# 3  4   4
# 4  5   5

# %%
# pd_s2 "2열" 컬럼을 만들고 데이터는 10 20 30 40 50 으로 추가
pd_s2['2열'] = [10,20,30,40,50]
pd_s2
# Out:
#    0  1열  2열
# 0  1   1  10
# 1  2   2  20
# 2  3   3  30
# 3  4   4  40
# 4  5   5  50

# %%
pd_s2.columns
# Out:
# Index([0, '1열', '2열'], dtype='object')

# %%
# 데이터프레임의 열 이름을 변경
pd_s3=pd_s2.rename(columns={0:'0열'})
pd_s3
# Out:
#    0열  1열  2열
# 0   1   1  10
# 1   2   2  20
# 2   3   3  30
# 3   4   4  40
# 4   5   5  50

# %%
pd_s3['0열'] = [11,12,13,14,15]
pd_s3['3열'] = [0,0,0,0,0]
pd_s3
# Out:
#    0열  1열  2열  3열
# 0  11   1  10   0
# 1  12   2  20   0
# 2  13   3  30   0
# 3  14   4  40   0
# 4  15   5  50   0

# %%
t_dic = {}
t_dic['0열'] = 10
t_dic['1열'] = 20
t_dic['2열'] = 30
t_dic['3열'] = 40
t_dic
# Out:
# {'0열': 10, '1열': 20, '2열': 30, '3열': 40}

# %%
# 컬럼명은 이름
# 데이터는 홍길동, 김길동
# 데이터 프레임으로 만들기
temp=pd.DataFrame(['홍길동','김길동'])
temp = temp.rename(columns={0:'이름'})
temp
# Out:
#     이름
# 0  홍길동
# 1  김길동

# %%
# 기존 데이터프레임에 나이 컬럼 추가
# 데이터는 10 20
temp['나이'] = [10,20]
temp
# Out:
#     이름  나이
# 0  홍길동  10
# 1  김길동  20

# %% [markdown]
# ###2차원 리스트를 데이터프레임으로 변환하기

# %%
# 각 행과 열이 됨
score=[
    ['정약용', 70, 80, 100],
    ['이순신', 100, 80, 70],
    ['이율곡', 90, 95, 90]
  ]
print(type(score))
score
# Out:
# <class 'list'>
# [['정약용', 70, 80, 100], ['이순신', 100, 80, 70], ['이율곡', 90, 95, 90]]

# %%
score_df=pd.DataFrame(score)
print(type(score_df))
score_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      0    1   2    3
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %%
list(score_df.columns)
# Out:
# [0, 1, 2, 3]

# %%
score_df.columns=['성명', '국어', '영어', '수학']
score_df
# Out:
#     성명   국어  영어   수학
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %%
score_df_r=score_df.rename(columns={'국어':'korean', '영어':'english', '수학':'math'})
score_df_r
# Out:
#     성명  korean  english  math
# 0  정약용      70       80   100
# 1  이순신     100       80    70
# 2  이율곡      90       95    90

# %%
score_df_r.values
# Out:
# array([['정약용', 70, 80, 100],
#        ['이순신', 100, 80, 70],
#        ['이율곡', 90, 95, 90]], dtype=object)

# %%
# 학생 데이터프레임
#컬럼명 이름, 나이, 주소, 점수, 취미
# 각각의 데이터는 임의로 생성해서
name = ['홍길동','김길동']
age = [10,20]
address = ['서울시','부산시']
score = [100,80]
hobby = ['독서','운동']
temp_2list = []
for i in range(2):
  temp_2list.append([name[i],age[i],address[i],score[i],hobby[i]])

temp = pd.DataFrame(temp_2list)
temp.columns = ['이름','나이','주소','점수','취미']
temp
# Out:
#     이름  나이   주소   점수  취미
# 0  홍길동  10  서울시  100  독서
# 1  김길동  20  부산시   80  운동

# %% [markdown]
# ###딕셔너리를 데이터프레임으로 만들기

# %%
temp = pd.DataFrame([1,2,3])
temp['나이'] = [10,20,30]
temp
# Out:
#    0  나이
# 0  1  10
# 1  2  20
# 2  3  30

# %%
score_dict={'성명': ['정약용', '이순신', '이율곡'],
 '국어': [70, 80, 100],
 '영어': [100, 80, 70],
 '수학': [90, 95, 90]}
print(score_dict, type(score_dict))
# Out:
# {'성명': ['정약용', '이순신', '이율곡'], '국어': [70, 80, 100], '영어': [100, 80, 70], '수학': [90, 95, 90]} <class 'dict'>

# %%
score_dict_df=pd.DataFrame(score_dict)
print(type(score_dict_df))
score_dict_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     성명   국어   영어  수학
# 0  정약용   70  100  90
# 1  이순신   80   80  95
# 2  이율곡  100   70  90

# %%
# 데이터의 모양을 나타낸다
# 2차원데이터는 행렬 즉  4 x 5
score_dict_df.shape
# Out:
# (3, 4)

# %%
score_dict_df.index # 행의 인덱스
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
score_dict_df.columns # 열 이름 목록, object는 문자열
# Out:
# Index(['성명', '국어', '영어', '수학'], dtype='object')

# %%
score_dict_df.values
# Out:
# array([['정약용', 70, 100, 90],
#        ['이순신', 80, 80, 95],
#        ['이율곡', 100, 70, 90]], dtype=object)

# %%
n=pd.DataFrame({'col_str1':['1', '2', '3', '4'],
 'col_str2':['5', '6', '7', '8']})
print(n)
# data types 의 약자로 각 컬럼의 데이터 타입
n.dtypes
# Out:
#   col_str1 col_str2
# 0        1        5
# 1        2        6
# 2        3        7
# 3        4        8
# col_str1    object
# col_str2    object
# dtype: object

# %%
# 각 컬럼에 해당하는 데이터의 타입을 변경한다
n_df=n.astype({'col_str1':int, 'col_str2':float})
print(n_df)
n_df.dtypes
# Out:
#    col_str1  col_str2
# 0         1       5.0
# 1         2       6.0
# 2         3       7.0
# 3         4       8.0
# col_str1      int64
# col_str2    float64
# dtype: object

# %% [markdown]
# ### <여기서 잠깐> 판다스의 데이터형

# %%
score_dict_df.dtypes
# Out:
# 성명    object
# 국어     int64
# 영어     int64
# 수학     int64
# dtype: object

# %%
# 딕셔너리 구조를 이용해서
# 이름 학년 점수 를 가지는 데이터 프레임
pd.DataFrame(
    {
      '이름':['홍길동','김길동'],
      '학년':[1,2],
      '점수':[100,80]
    }
  )
# Out:
#     이름  학년   점수
# 0  홍길동   1  100
# 1  김길동   2   80

# %% [markdown]
# ##2. 데이터프레임 사용
# ### 특정 열을 인덱스로 지정하기

# %%
score_dict_df
# Out:
#     성명   국어   영어  수학
# 0  정약용   70  100  90
# 1  이순신   80   80  95
# 2  이율곡  100   70  90

# %%
score_dict_df['성명']
# Out:
# 0    정약용
# 1    이순신
# 2    이율곡
# Name: 성명, dtype: object

# %%
score_dict_df.index = score_dict_df['성명']
score_dict_df
# Out:
#       성명   국어   영어  수학
# 성명
# 정약용  정약용   70  100  90
# 이순신  이순신   80   80  95
# 이율곡  이율곡  100   70  90

# %%
score_dict_df.index=score_dict_df['성명']
print(type(score_dict_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ###행/열 삭제하기

# %%
score_dict_df
# Out:
#       성명   국어   영어  수학
# 성명
# 정약용  정약용   70  100  90
# 이순신  이순신   80   80  95
# 이율곡  이율곡  100   70  90

# %%
# axis는 기본이 0
# axis는 축의 정보
# 2차원데이터 shape ( x, x, x)
# axis               0   1  2
score_dict_df.drop(['성명'], axis=1)
# Out:
#       국어   영어  수학
# 성명
# 정약용   70  100  90
# 이순신   80   80  95
# 이율곡  100   70  90

# %%
score_dict_df.drop(['이순신'], axis=0)
# Out:
#       성명   국어   영어  수학
# 성명
# 정약용  정약용   70  100  90
# 이율곡  이율곡  100   70  90

# %%
#  axis = 0 이 기본
score_dict_df.drop(score_dict_df.index[2])
# Out:
#       성명  국어   영어  수학
# 성명
# 정약용  정약용  70  100  90
# 이순신  이순신  80   80  95

# %% [markdown]
# ### <여기서 잠깐> 행 데이터를 완전히 삭제하기

# %%
score_dict_df
# Out:
#       성명   국어   영어  수학
# 성명
# 정약용  정약용   70  100  90
# 이순신  이순신   80   80  95
# 이율곡  이율곡  100   70  90

# %%
# 원본을 변경하지 않고 결과만 리턴하는데. inplace를 True로 하면 원본이 변경된다
score_dict_df.drop(['성명'], axis=1,inplace=True)
score_dict_df
# Out:
#       국어   영어  수학
# 성명
# 정약용   70  100  90
# 이순신   80   80  95
# 이율곡  100   70  90

# %%
# 1. 임의의 데이터프레임 생성
# 2. 특정 컬럼의 데이터를 인덱스로 대처
# 3. 인덱스로 대처한 컬럼을 삭제(원본도)
# 4. 특정 컬럼데이터, 인덱스 데이터를 삭제
import random
temp_dic = {
    'col1' : [ random.randint(1,20) for i in range(10) ],
    'col2' : [ random.randint(1,20) for i in range(10) ],
    'col3' : [ random.randint(1,20) for i in range(10) ],
    'col4' : [ random.randint(1,20) for i in range(10) ]
}
df = pd.DataFrame(temp_dic)
df.index = df['col1']
df.drop(['col1'],axis=1,inplace=True)
df = df.drop(['col3'],axis=1)
df
# Out:
#       col2  col4
# col1
# 7       13    16
# 4       18     5
# 3       11     1
# 3       20    15
# 5        7    17
# 11      15    20
# 12      17    16
# 1        3     6
# 13       9     6
# 7       20    12

# %%
# df.drop([11],inplace=True)
# df

# %%
# 학생데이터를 만들어서 인덱스로 이름을 지정
# 4명의 학생에 대해서 국 영 수 를 임의로 셋팅해서 DF로 표현
import random
students = pd.DataFrame(
    {
        '이름':['이씨','김씨','박씨','최씨'],
        '국어':[random.randint(80,100) for i in range(4)],
        '영어':[random.randint(80,100) for i in range(4)],
        '수학':[random.randint(80,100) for i in range(4)],
    }
)
students.index = students['이름']
students.drop([students.columns[0]],axis=1, inplace=True)
students['합'] = students['국어'] + students['영어'] + students['수학']
students['평균'] = round( students['합'] / 3, 2)
students
# Out:
#     국어   영어  수학    합     평균
# 이름
# 이씨  96   85  82  263  87.67
# 김씨  82  100  83  265  88.33
# 박씨  92   81  95  268  89.33
# 최씨  87   91  83  261  87.00

# %% [markdown]
# ##3. 유용한 데이터프레임 조작 기능

# %%
import pandas as pd
x=[0, 1, 2, 3, 4, 5]
y=[0, 2, 4, 6, 8, 10]
df=pd.DataFrame( )
df['x_value']=x
df['y_value']=y
df
# Out:
#    x_value  y_value
# 0        0        0
# 1        1        2
# 2        2        4
# 3        3        6
# 4        4        8
# 5        5       10

# %%
df['xy_value']=df['x_value'] * df['y_value']
df
# Out:
#    x_value  y_value  xy_value
# 0        0        0         0
# 1        1        2         2
# 2        2        4         8
# 3        3        6        18
# 4        4        8        32
# 5        5       10        50

# %% [markdown]
# ###인덱스 새로 지정하기: set_index 함수

# %%
index=['zero', 'one', 'two', 'three', 'four', 'five']
df['number']=index
# df.index = df['number']
# df.drop(['number'], axis=1)
df
# Out:
#    x_value  y_value  xy_value number
# 0        0        0         0   zero
# 1        1        2         2    one
# 2        2        4         8    two
# 3        3        6        18  three
# 4        4        8        32   four
# 5        5       10        50   five

# %% [markdown]
# ####[기존 인덱스 유지하기]

# %%
df.set_index('number', append=True)
# Out:
#           x_value  y_value  xy_value
#   number
# 0 zero          0        0         0
# 1 one           1        2         2
# 2 two           2        4         8
# 3 three         3        6        18
# 4 four          4        8        32
# 5 five          5       10        50

# %% [markdown]
# ####[기존 인덱스 지우기]

# %%
df2=df.set_index('number')
df2
# Out:
#         x_value  y_value  xy_value
# number
# zero          0        0         0
# one           1        2         2
# two           2        4         8
# three         3        6        18
# four          4        8        32
# five          5       10        50

# %%
df2.reset_index()
# Out:
#   number  x_value  y_value  xy_value
# 0   zero        0        0         0
# 1    one        1        2         2
# 2    two        2        4         8
# 3  three        3        6        18
# 4   four        4        8        32
# 5   five        5       10        50

# %% [markdown]
# ###기존 인덱스 삭제하고 초기화하기: reset_index 함수

# %%
df3=df2.reset_index(drop=True)
df3
# Out:
#    x_value  y_value  xy_value
# 0        0        0         0
# 1        1        2         2
# 2        2        4         8
# 3        3        6        18
# 4        4        8        32
# 5        5       10        50

# %% [markdown]
# ###날짜로 인덱스 만들기: pd.date_range 함수

# %%
dates=pd.date_range('20240701', periods=6)
dates
# Out:
# DatetimeIndex(['2024-07-01', '2024-07-02', '2024-07-03', '2024-07-04',
#                '2024-07-05', '2024-07-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df4=df2.reset_index(drop=True)
df5=df4.set_index(dates)
df5
# Out:
#             x_value  y_value  xy_value
# 2024-07-01        0        0         0
# 2024-07-02        1        2         2
# 2024-07-03        2        4         8
# 2024-07-04        3        6        18
# 2024-07-05        4        8        32
# 2024-07-06        5       10        50

# %% [markdown]
# ###index 속성으로 인덱스 추출하기

# %%
df5.index
# Out:
# DatetimeIndex(['2024-07-01', '2024-07-02', '2024-07-03', '2024-07-04',
#                '2024-07-05', '2024-07-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ###value 속성으로 행 데이터 추출하기

# %%
df5.values
# Out:
# array([[ 0,  0,  0],
#        [ 1,  2,  2],
#        [ 2,  4,  8],
#        [ 3,  6, 18],
#        [ 4,  8, 32],
#        [ 5, 10, 50]])

# %%
# 배운내용 확인하기
# 1. 데이터 프레임, 시리즈
# 2. 데이터 프레임 만들기 : dictionary로 만들면 키가 컬럼이 된다.
# 3. 데이터 프레임[컬럼명] : 해당 컬럼의 데이터를 가지는 시리즈가 된다
# 3. 데이터 프레임[ [컬럼명] ] : 해당 컬럼의 데이터를 가지는 데이터프레임
# 4. drop : axis 에따라서 행 또는 열을 제거한다
# 5. 인덱스 : 기본적으로 0부터 시퀀스한 인덱스가 생성되는데
  # index = 컬럼데이터
  # set_index 함수를 이용
  # reset_index 함수는 인덱스 컬럼으로 복귀 또는 복귀안하고 초기화
  # pd.date_range 함수 날짜로 인덱스를 만들수 있음 --> 시계열데이터에 적합한 구조
# 6. shape
# 7. astype
# 8. 새로운 컬럼 추가 또는 수정
# 9. 각 컬럼별로 연산이 가능하다 합계, 평균

# %%
# 1, 2, 3,4,5
import pandas as pd
df = pd.DataFrame(
    {
      '이름':['홍길동','김길동'],
      '학년':[1,2],
      '점수':[100,80]
    }
  )
se = pd.Series([100,80])
# df.index = df['이름']
# df.drop(['이름'],axis=1)
df = df.set_index('이름')
df = df.reset_index()
df.set_index(pd.date_range('20240701', periods=2))
# 학년 * 점수 new라는 컬럼
df['new'] = df['학년'] * df['점수']
df
# Out:
#     이름  학년   점수  new
# 0  홍길동   1  100  100
# 1  김길동   2   80  160

# %% [markdown]
# ###차트 만들기: plot 함수

# %%
df2
# Out:
#         x_value  y_value  xy_value
# number
# zero          0        0         0
# one           1        2         2
# two           2        4         8
# three         3        6        18
# four          4        8        32
# five          5       10        50

# %%
df2.plot( )
# Out:
# <Axes: xlabel='number'>

# %% [markdown]
# ###특정 열을 기준으로 정렬하기: sort_values 함수

# %%
df5.sort_values(by='x_value', ascending=False) # x_value 열을 기준으로 내림차순 정렬
# Out:
#             x_value  y_value  xy_value       mean
# 2024-07-06        5       10        50  21.666667
# 2024-07-05        4        8        32  14.666667
# 2024-07-04        3        6        18   9.000000
# 2024-07-03        2        4         8   4.666667
# 2024-07-02        1        2         2   1.666667
# 2024-07-01        0        0         0   0.000000

# %% [markdown]
# ###평균값 열 추가하기: mean 함수

# %%
df5['mean']=df5.mean(axis=1)
df5
# Out:
#             x_value  y_value  xy_value       mean
# 2024-07-01        0        0         0   0.000000
# 2024-07-02        1        2         2   1.666667
# 2024-07-03        2        4         8   4.666667
# 2024-07-04        3        6        18   9.000000
# 2024-07-05        4        8        32  14.666667
# 2024-07-06        5       10        50  21.666667

# %%
# 각 분기별(4분기) 영업사원의 실적을 그래프로 표현

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import random
pd = pd.DataFrame(
    {
      'name':['hong','kim','lee','choi','bark'],
      '1/4':[random.randint(50,100) for i in range(5)],
      '2/4':[random.randint(50,100) for i in range(5)],
      '3/4':[random.randint(50,100) for i in range(5)],
      '4/4':[random.randint(50,100) for i in range(5)],
    }
  )
pd = pd.set_index('name')
pd.plot()
# Out:
# <Axes: xlabel='name'>
